# %% [markdown]
# # Data sets

# %%
import pprint

import matplotlib.pyplot as plt

from pysilsub.device import StimulationDevice

# %%
sd = StimulationDevice.from_json('../data/STLAB_1_York.json')

fig, axs = plt.subplots(1, 2, figsize=(12, 5))
sd.plot_spds(ax=axs[0])
sd.plot_gamut(ax=axs[1])

pprint.pprint(sd.config)
# Out:
# {'colors': ['blueviolet',
#             'royalblue',
#             'darkblue',
#             'blue',
#             'cyan',
#             'green',
#             'lime',
#             'orange',
#             'red',
#             'darkred'],
#  'json_name': 'STLAB_1_York',
#  'name': 'STLAB_1 (binocular, left eye)',
#  'notes': 'STLAB_1 is used in the psychology department at the University of '
#           'York to stimulate the left eye in a binocular stimulation setup for '
#           'the BakerWadeBBSRC project. For this setup, light is transported '
#           'from STLAB via liquid light guides and diffused by discs of white '
#           'diffuser glass, which are fused into a single image courtesy of a '
#           'VR headset. Measurements taken with an OceanOptics JAZ spectrometer '
#           'through the VR goggles.',
#  'resolutions': [4095, 4095, 4095, 4095, 4095, 4095, 4095, 4095, 4095, 4095],
# ...

# %%
sd = StimulationDevice.from_json('../data/STLAB_2_York.json')

fig, axs = plt.subplots(1, 2, figsize=(12, 5))
sd.plot_spds(ax=axs[0])
sd.plot_gamut(ax=axs[1])

pprint.pprint(sd.config)
# Out:
# {'colors': ['blueviolet',
#             'royalblue',
#             'darkblue',
#             'blue',
#             'cyan',
#             'green',
#             'lime',
#             'orange',
#             'red',
#             'darkred'],
#  'json_name': 'STLAB_2_York',
#  'name': 'STLAB_2 (binocular, right eye)',
#  'notes': 'STLAB_2 is used in the psychology department at the University of '
#           'York to stimulate the right eye in a binocular stimulation setup '
#           'for the BakerWadeBBSRC project. For this setup, light is '
#           'transported from STLAB via liquid light guides and diffused by '
#           'discs of white diffuser glass, which are fused into a single image '
#           'courtesy of a VR headset. Measurements taken with an OceanOptics '
#           'JAZ spectrometer through the VR goggles.',
#  'resolutions': [4095, 4095, 4095, 4095, 4095, 4095, 4095, 4095, 4095, 4095],
# ...

# %%
sd = StimulationDevice.from_json('../data/STLAB_1_Oxford.json')

fig, axs = plt.subplots(1, 2, figsize=(12, 5))
sd.plot_spds(ax=axs[0])
sd.plot_gamut(ax=axs[1])

pprint.pprint(sd.config)
# Out:
# {'colors': ['blueviolet',
#             'royalblue',
#             'darkblue',
#             'blue',
#             'cyan',
#             'green',
#             'lime',
#             'orange',
#             'red',
#             'darkred'],
#  'json_name': 'STLAB_1_Oxford',
#  'name': 'STLAB_1 (sphere)',
#  'notes': 'STLAB_1 (sphere) is a Ganzfeld stimulation system. Spectral '
#           'measurements obtained with an OceanOptics STS-VIS spectrometer.',
#  'resolutions': [4095, 4095, 4095, 4095, 4095, 4095, 4095, 4095, 4095, 4095],
#  'spds': '/Users/jtm545/Projects/PyPlr/data/STLAB_Oxford/S1_corrected_oo_spectra.csv',
#  'spds_units': 'W/m$^2$/nm',
#  'wavelengths': [380, 781, 1]}

# %%
sd = StimulationDevice.from_json('../data/STLAB_2_Oxford.json')

fig, axs = plt.subplots(1, 2, figsize=(12, 5))
sd.plot_spds(ax=axs[0])
sd.plot_gamut(ax=axs[1])

pprint.pprint(sd.config)
# Out:
# {'colors': ['blueviolet',
#             'royalblue',
#             'darkblue',
#             'blue',
#             'cyan',
#             'green',
#             'lime',
#             'orange',
#             'red',
#             'darkred'],
#  'json_name': 'STLAB_2_Oxford',
#  'name': 'STLAB_2 (sphere)',
#  'notes': 'STLAB_2 (sphere) is a Ganzfeld stimulation system. Spectral '
#           'measurements obtained with an OceanOptics STS-VIS spectrometer.',
#  'resolutions': [4095, 4095, 4095, 4095, 4095, 4095, 4095, 4095, 4095, 4095],
#  'spds': '/Users/jtm545/Projects/PyPlr/data/STLAB_Oxford/S2_corrected_oo_spectra.csv',
#  'spds_units': 'W/m$^2$/nm',
#  'wavelengths': [380, 781, 1]}

# %%
sd = StimulationDevice.from_json('../data/BCGAR.json')

fig, axs = plt.subplots(1, 2, figsize=(12, 5))
sd.plot_spds(ax=axs[0])
sd.plot_gamut(ax=axs[1])

pprint.pprint(sd.config)
# Out:
# {'colors': ['blue', 'cyan', 'green', 'orange', 'red'],
#  'json_name': 'BCGAR',
#  'name': 'BCGAR (8-bit, linear)',
#  'notes': 'An artificial 8-bit linear calibration based on the maximum output '
#           'of 5 STLAB channels',
#  'resolutions': [255, 255, 255, 255, 255],
#  'spds': '/Users/jtm545/Projects/PySilSub/data/BCGAR_5_Primary_8_bit_linear.csv',
#  'spds_units': 'W/m$^2$/nm',
#  'wavelengths': [380, 781, 1]}

# %%
sd = StimulationDevice.from_json('../data/VirtualSky.json')

fig, axs = plt.subplots(1, 2, figsize=(12, 5))
sd.plot_spds(ax=axs[0])
sd.plot_gamut(ax=axs[1])

pprint.pprint(sd.config)
# Out:
# {'colors': ['blue', 'green', 'red', 'darkgrey'],
#  'json_name': 'VirtualSky',
#  'name': 'VirtualSky (BGRW projector)',
#  'notes': 'The device is a BGRW projector with a likely 8-bit native '
#           'resolution. Though the data have been wrangled and given a '
#           'fictitious resolution, the spectral measurements are taken from the '
#           'device accross its native resolution. This is included as an '
#           'example of a 4-primary system.',
#  'resolutions': [260, 260, 260, 260],
#  'spds': '/Users/jtm545/Projects/PySilSub/data/VirtualSky.csv',
#  'spds_units': 'Flux',
#  'wavelengths': [380, 781, 1]}

# %%
sd = StimulationDevice.from_json('../data/OneLight.json')

fig, axs = plt.subplots(1, 2, figsize=(12, 5))
sd.plot_spds(ax=axs[0], **{'legend': False})
sd.plot_gamut(ax=axs[1])

pprint.pprint(sd.config)
# Out:
# {'colors': [[0.3415609381007305, 0.3448673587081892, 0.6519031141868512],
#             [0.31449442522106885, 0.37993079584775086, 0.6685121107266436],
#             [0.2806612841214917, 0.423760092272203, 0.6892733564013841],
#             [0.25359477124183005, 0.45882352941176474, 0.7058823529411765],
#             [0.21976163014225297, 0.5026528258362168, 0.726643598615917],
#             [0.20007689350249905, 0.5377931564782776, 0.7393310265282584],
#             [0.24006151480199925, 0.58239138792772, 0.7208765859284891],
#             [0.27204921184159936, 0.6180699730872741, 0.7061130334486736],
#             [0.31203383314109956, 0.6626682045367166, 0.6876585928489043],
#             [0.34402153018069975, 0.6983467896962706, 0.6728950403690889],
#             [0.38400615148019995, 0.7429450211457131, 0.6544405997693196],
#             [0.42122260668973477, 0.7690888119953864, 0.6467512495194156],
#             [0.47427912341407163, 0.7898500576701268, 0.6459823144944252],
# ...
