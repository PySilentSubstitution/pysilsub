# %%
from scipy.interpolate import CubicSpline
import matplotlib.pyplot as plt

from pysilsub.problem import SilentSubstitutionProblem as SSP

# Which device to use

#ssp = SSP.from_json('../data/STLAB_1_York.json')
ssp = SSP.from_json('../data/STLAB_2_York.json')
#ssp = SSP.from_json('../data/STLAB_1_Oxford.json')
#ssp = SSP.from_json('../data/STLAB_2_Oxford.json')
#ssp = SSP.from_json('../data/BCGAR_8_bit_linear.json')
#ssp = SSP.from_json('../data/OneLight.json')
#ssp = SSP.from_json('../data/VirtualSky.json')
#ssp = SSP.from_json('../data/LEDCube.json')



ssp.do_gamma()
_ = ssp.fit_curves()
# Out:
# /Users/jtm545/Projects/PySilSub/pysilsub/device.py:698: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()

# %%
for idx, primary in ssp.gamma.iterrows():
    primary.plot(c=ssp.colors[idx])

# %%
for primary in range(10):
    for setting in range(0, 4096, 65):
        plt.plot(ssp.predict_primary_spd(primary, setting), c=ssp.colors[primary], lw=1)

# %%
for primary in range(10):
    for setting in range(0, 4096, 65):
        s = ssp.gamma_lookup(primary, setting)
        plt.plot(ssp.predict_primary_spd(primary, s), c=ssp.colors[primary], lw=1)
