# %%
import numpy as np
import pandas as pd
from scipy.interpolate import interp1d
from scipy.stats import beta
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('notebook')
sns.set_style('darkgrid')

from pysilsub.device import StimulationDevice

d = StimulationDevice.from_json('../data/STLAB_2_York.json')

# %%
d.plot_calibration_spds()
# Out:
# <AxesSubplot:title={'center':'STLAB_2 (binocular, right eye) SPDs'}, xlabel='Wavelength (nm)', ylabel='Counts/s/nm'>

# %% [markdown]
# # 7th order polynomial

# %%
d.do_gamma(fit='polynomial')
d.plot_gamma(show_corrected=True)

# %% [markdown]
# # beta cdfs

# %%
d.do_gamma(fit='beta_cdf')
d.plot_gamma(show_corrected=True)
