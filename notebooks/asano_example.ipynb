# %%
import matplotlib.pyplot as plt
from pysilsub.CIE import get_CIES026
from pysilsub.asano import CIE2006_LMS_CMFs

# %matplotlib inline

# %%
fig, ax = plt.subplots()
sss = get_CIES026(binwidth=5)[['L','M','S']]
individual_sss = CIE2006_LMS_CMFs(age=20, field_size=10)

sss.plot(color=['r','g','b'], ax=ax)
individual_sss.plot(ax=ax, color=['r','g','b'], ls=':')
# Out:
# <AxesSubplot:xlabel='Wavelength'>

# %%
individual_sss
