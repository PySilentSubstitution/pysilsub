# %% [markdown]
# Prereceptoral filtering
# =======================
#
# Before incident light hits retinal photoreceptors it first travels through the crystalline lens and other ocular media. The lens contains a yellow pigment which accumulates with age due to absorption of UV light, and the macular contains

# %% [markdown]
# Lens yellowing with age
# -----------------------
#
# <div style="text-align: center;">
# <figure>
# <img src="../../img/lensesAge.jpg" width="300" height="300" />
#   <figcaption>Lens yellowing with age.</figcaption>
# </figure>
# </div>

# %% [markdown]
# Macular pigment
# ---------------
#
# <div style="text-align: center;">
# <figure>
# <img src="../../img/fundus.png" width="300" height="300" />
#   <figcaption>Human fundus diagram showing macular pigment.</figcaption>
# </figure>
# </div>
